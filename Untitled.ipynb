# %%
import time 
import numpy as np
import tqdm
import os 
import subprocess
import pandas as pd 

import pickle

columns = ['Destination Port', 'Flow Duration', 'Total Fwd Packets',
       'Total Backward Packets', 'Total Length of Fwd Packets',
       'Total Length of Bwd Packets', 'Fwd Packet Length Max',
       'Fwd Packet Length Min', 'Fwd Packet Length Mean',
       'Fwd Packet Length Std', 'Bwd Packet Length Max',
       'Bwd Packet Length Min', 'Bwd Packet Length Mean',
       'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
       'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
       'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
       'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
       'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
       'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
       'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
       'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
       'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
       'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
       'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
       'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size',
       'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate',
       'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate',
       'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets',
       'Subflow Bwd Bytes', 'Init_Win_bytes_forward',
       'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
       'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
       'Idle Std', 'Idle Max', 'Idle Min', 'Label']


columns_to_drop =['Flow ID', 'Src IP', 'Src Port', 'Dst IP', 'Protocol','Timestamp' ]



def process_data(df):
    def f1(x):
        if x == 'Infinity':
            return 1
        else:
            return 0
        
        
    def f(x):
        if x == 'BENIGN':
            return 0
        else:
            return 1

    df['Label'] = df['Label'].apply(f)
    
    df['isInfFB'] = df['Flow Bytes/s'].apply(f)

    df['isInfFP'] = df['Flow Packets/s'].apply(f)

    m = 10000#pd.to_numeric(df.loc[df['Flow Bytes/s'] != "Infinity", 'Flow Bytes/s']).max()
    df['Flow Bytes/s'].replace("Infinity",m,inplace=True)

#     m = pd.to_numeric(df.loc[df['Flow Packets/s'] != "Infinity", 'Flow Packets/s']).max()
    df['Flow Packets/s'].replace("Infinity",m,inplace=True)

    df['Flow Bytes/s'] = pd.to_numeric(df['Flow Bytes/s'])
    df['Flow Packets/s'] = pd.to_numeric(df['Flow Packets/s'])
    
    return df.dropna()

df = pd.read_csv('./output_folder/capture-output.pcap_Flow.csv',chunksize=1)


# now you can save it to a file
with open('model.pkl', 'rb') as f:
    model  = pickle.load(f)


with open('novelty_model.pkl', 'rb') as f:
    novelty_model  = pickle.load(f)


with open('outlier_model.pkl', 'rb') as f:
    outlier_model  = pickle.load(f)







for chunk in df:
    
    chunk.drop(columns_to_drop,axis=1,inplace=True)
#     print(chunk)
    chunk.columns = columns
    chunk = process_data(chunk)

#     print(chunk.columns)
    new_chunk = chunk.copy()

    new_chunk['novelty'] = novelty_model.decision_function(chunk.drop(['Label'],axis=1))

    new_chunk['outlier'] = outlier_model.decision_function(chunk.drop(['Label'],axis=1))

    result = model.predict(new_chunk.drop(['Label'],axis=1))

    if result == 1:
        print('DETECTED')
# Out:
# ['Destination Port', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets', 'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio', 'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
df = pd.read_csv('./output_folder/capture-output.pcap_Flow.csv')

# %%
df[df['Flow Bytes/s'] != "Infinity"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Flow Bytes/s'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-62a622ad7d0a> in <module>
# ----> 1 df[df['Flow Bytes/s'] != "Infinity"]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Flow Bytes/s'

# %%
df.drop(columns_to_drop,axis=1,inplace=True)
df.columns = columns

# %%
df['Flow Bytes/s'] != "Infinity", 'Flow Bytes/s']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 78 columns):
# Destination Port               12 non-null int64
# Flow Duration                  12 non-null int64
# Total Fwd Packets              12 non-null int64
# Total Backward Packets         12 non-null int64
# Total Length of Fwd Packets    12 non-null float64
# Total Length of Bwd Packets    12 non-null float64
# Fwd Packet Length Max          12 non-null float64
# Fwd Packet Length Min          12 non-null float64
# Fwd Packet Length Mean         12 non-null float64
# Fwd Packet Length Std          12 non-null float64
# Bwd Packet Length Max          12 non-null float64
# Bwd Packet Length Min          12 non-null float64
# Bwd Packet Length Mean         12 non-null float64
# Bwd Packet Length Std          12 non-null float64
# Flow Bytes/s                   12 non-null float64
# Flow Packets/s                 12 non-null float64
# Flow IAT Mean                  12 non-null float64
# Flow IAT Std                   12 non-null float64
# Flow IAT Max                   12 non-null float64
# Flow IAT Min                   12 non-null float64
# Fwd IAT Total                  12 non-null float64
# Fwd IAT Mean                   12 non-null float64
# Fwd IAT Std                    12 non-null float64
# Fwd IAT Max                    12 non-null float64
# Fwd IAT Min                    12 non-null float64
# Bwd IAT Total                  12 non-null float64
# Bwd IAT Mean                   12 non-null float64
# Bwd IAT Std                    12 non-null float64
# Bwd IAT Max                    12 non-null float64
# Bwd IAT Min                    12 non-null float64
# Fwd PSH Flags                  12 non-null int64
# Bwd PSH Flags                  12 non-null int64
# Fwd URG Flags                  12 non-null int64
# Bwd URG Flags                  12 non-null int64
# Fwd Header Length              12 non-null int64
# Bwd Header Length              12 non-null int64
# Fwd Packets/s                  12 non-null float64
# Bwd Packets/s                  12 non-null float64
# Min Packet Length              12 non-null float64
# Max Packet Length              12 non-null float64
# Packet Length Mean             12 non-null float64
# Packet Length Std              12 non-null float64
# Packet Length Variance         12 non-null float64
# FIN Flag Count                 12 non-null int64
# SYN Flag Count                 12 non-null int64
# RST Flag Count                 12 non-null int64
# PSH Flag Count                 12 non-null int64
# ACK Flag Count                 12 non-null int64
# URG Flag Count                 12 non-null int64
# CWE Flag Count                 12 non-null int64
# ECE Flag Count                 12 non-null int64
# Down/Up Ratio                  12 non-null float64
# Average Packet Size            12 non-null float64
# Avg Fwd Segment Size           12 non-null float64
# Avg Bwd Segment Size           12 non-null float64
# Fwd Avg Bytes/Bulk             12 non-null int64
# Fwd Avg Packets/Bulk           12 non-null int64
# Fwd Avg Bulk Rate              12 non-null int64
# Bwd Avg Bytes/Bulk             12 non-null int64
# Bwd Avg Packets/Bulk           12 non-null int64
# Bwd Avg Bulk Rate              12 non-null int64
# Subflow Fwd Packets            12 non-null int64
# Subflow Fwd Bytes              12 non-null int64
# Subflow Bwd Packets            12 non-null int64
# Subflow Bwd Bytes              12 non-null int64
# Init_Win_bytes_forward         12 non-null int64
# Init_Win_bytes_backward        12 non-null int64
# act_data_pkt_fwd               12 non-null int64
# min_seg_size_forward           12 non-null int64
# Active Mean                    12 non-null float64
# Active Std                     12 non-null float64
# Active Max                     12 non-null float64
# Active Min                     12 non-null float64
# Idle Mean                      12 non-null float64
# Idle Std                       12 non-null float64
# Idle Max                       12 non-null float64
# Idle Min                       12 non-null float64
# Label                          12 non-null object
# dtypes: float64(45), int64(32), object(1)
# memory usage: 7.4+ KB
